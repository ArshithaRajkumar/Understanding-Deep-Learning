# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshithaRajkumar/Understanding-Deep-Learning/blob/main/Notebooks/Chap12/12_3_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 12.3: Tokenization**
#
# This notebook builds set of tokens from a text string as in figure 12.8 of the book.

# %%
import re, collections

# %%
# text = "a sailor went to sea sea sea "+\
#                   "to see what he could see see see "+\
#                   "but all that he could see see see "+\
#                   "was the bottom of the deep blue sea sea sea"
text= "How much wood could a woodchuck chuck if a woodchuck could chuck wood"

# %% [markdown]
# Tokenize the input sentence To begin with the tokens are the individual letters and the </w> whitespace token. So, we represent each word in terms of these tokens with spaces between the tokens to delineate them.
#
# The tokenized text is stored in a structure that represents each word as tokens together with the count of how often that word occurs.  We'll call this the *vocabulary*.

# %%
def initialize_vocabulary(text):
  vocab = collections.defaultdict(int)
  words = text.strip().split()
  for word in words:
      vocab[' '.join(list(word)) + ' </w>'] += 1
  return vocab

# %%
vocab = initialize_vocabulary(text)
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Vocabulary: defaultdict(<class 'int'>, {'H o w </w>': 1, 'm u c h </w>': 1, 'w o o d </w>': 2, 'c o u l d </w>': 2, 'a </w>': 2, 'w o o d c h u c k </w>': 2, 'c h u c k </w>': 2, 'i f </w>': 1})
# Size of vocabulary: 8

# %% [markdown]
# Find all the tokens in the current vocabulary and their frequencies

# %%
def get_tokens_and_frequencies(vocab):
  tokens = collections.defaultdict(int)
  for word, freq in vocab.items():
      word_tokens = word.split()
      for token in word_tokens:
          tokens[token] += freq
  return tokens

# %%
tokens = get_tokens_and_frequencies(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 11, 'w': 5, '</w>': 13, 'm': 1, 'u': 7, 'c': 11, 'h': 5, 'd': 6, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 14

# %% [markdown]
# Find each pair of adjacent tokens in the vocabulary
# and count them.  We will subsequently merge the most frequently occurring pair.

# %%
def get_pairs_and_counts(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq
    return pairs

# %%
pairs = get_pairs_and_counts(vocab)
print('Pairs: {}'.format(pairs))
print('Number of distinct pairs: {}'.format(len(pairs)))

most_frequent_pair = max(pairs, key=pairs.get)
print('Most frequent pair: {}'.format(most_frequent_pair))
# Out:
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'u'): 1, ('u', 'c'): 5, ('c', 'h'): 5, ('h', '</w>'): 1, ('w', 'o'): 4, ('o', 'o'): 4, ('o', 'd'): 4, ('d', '</w>'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('a', '</w>'): 2, ('d', 'c'): 2, ('h', 'u'): 4, ('c', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 22
# Most frequent pair: ('u', 'c')

# %% [markdown]
# Merge the instances of the best pair in the vocabulary

# %%
def merge_pair_in_vocabulary(pair, vocab_in):
    vocab_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in vocab_in:
        word_out = p.sub(''.join(pair), word)
        vocab_out[word_out] = vocab_in[word]
    return vocab_out

# %%
vocab = merge_pair_in_vocabulary(most_frequent_pair, vocab)
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Vocabulary: {'H o w </w>': 1, 'm uc h </w>': 1, 'w o o d </w>': 2, 'c o u l d </w>': 2, 'a </w>': 2, 'w o o d c h uc k </w>': 2, 'c h uc k </w>': 2, 'i f </w>': 1}
# Size of vocabulary: 8

# %% [markdown]
# Update the tokens, which now include the best token 'se'

# %%
tokens = get_tokens_and_frequencies(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 11, 'w': 5, '</w>': 13, 'm': 1, 'uc': 5, 'h': 5, 'd': 6, 'c': 6, 'u': 2, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 15

# %% [markdown]
# Now let's write the full tokenization routine

# %%
# TODO -- write this routine by filling in this missing parts,
# calling the above routines
def tokenize(text, num_merges):
  # Initialize the vocabulary from the input text
  # vocab = (your code here)
  vocab = initialize_vocabulary(text)
  print('Vocabulary: {}'.format(vocab))
  print('Size of vocabulary: {}'.format(len(vocab)))

  # Tokenize the input text

  for i in range(num_merges):
    # Find the tokens and how often they occur in the vocabulary
    # tokens = (your code here)
    tokens = get_tokens_and_frequencies(vocab)
    print('Tokens: {}'.format(tokens))
    print('Number of tokens: {}'.format(len(tokens)))

    # Find the pairs of adjacent tokens and their counts
    # pairs = (your code here)
    pairs = get_pairs_and_counts(vocab)
    print('Pairs: {}'.format(pairs))
    print('Number of distinct pairs: {}'.format(len(pairs)))


    # Find the most frequent pair
    # most_frequent_pair = (your code here)
    most_frequent_pair = max(pairs, key=pairs.get)
    print('Most frequent pair: {}'.format(most_frequent_pair))

    # Merge the code in the vocabulary
    # vocab = (your code here)
    vocab = merge_pair_in_vocabulary(most_frequent_pair, vocab)
  # Find the tokens and how often they occur in the vocabulary one last time
  # tokens = (your code here)
  tokens = get_tokens_and_frequencies(vocab)
  print('Tokens: {}'.format(tokens))
  print('Number of tokens: {}'.format(len(tokens)))

  return tokens, vocab

# %%
tokens, vocab = tokenize(text, num_merges=24)
# Out:
# Vocabulary: defaultdict(<class 'int'>, {'H o w </w>': 1, 'm u c h </w>': 1, 'w o o d </w>': 2, 'c o u l d </w>': 2, 'a </w>': 2, 'w o o d c h u c k </w>': 2, 'c h u c k </w>': 2, 'i f </w>': 1})
# Size of vocabulary: 8
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 11, 'w': 5, '</w>': 13, 'm': 1, 'u': 7, 'c': 11, 'h': 5, 'd': 6, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 14
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'u'): 1, ('u', 'c'): 5, ('c', 'h'): 5, ('h', '</w>'): 1, ('w', 'o'): 4, ('o', 'o'): 4, ('o', 'd'): 4, ('d', '</w>'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('a', '</w>'): 2, ('d', 'c'): 2, ('h', 'u'): 4, ('c', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 22
# Most frequent pair: ('u', 'c')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 11, 'w': 5, '</w>': 13, 'm': 1, 'uc': 5, 'h': 5, 'd': 6, 'c': 6, 'u': 2, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 15
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('w', 'o'): 4, ('o', 'o'): 4, ('o', 'd'): 4, ('d', '</w>'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('a', '</w>'): 2, ('d', 'c'): 2, ('c', 'h'): 4, ('h', 'uc'): 4, ('uc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 22
# Most frequent pair: ('w', 'o')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 7, 'w': 1, '</w>': 13, 'm': 1, 'uc': 5, 'h': 5, 'wo': 4, 'd': 6, 'c': 6, 'u': 2, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wo', 'o'): 4, ('o', 'd'): 4, ('d', '</w>'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('a', '</w>'): 2, ('d', 'c'): 2, ('c', 'h'): 4, ('h', 'uc'): 4, ('uc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 21
# Most frequent pair: ('wo', 'o')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 13, 'm': 1, 'uc': 5, 'h': 5, 'woo': 4, 'd': 6, 'c': 6, 'u': 2, 'l': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('woo', 'd'): 4, ('d', '</w>'): 4, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('a', '</w>'): 2, ('d', 'c'): 2, ('c', 'h'): 4, ('h', 'uc'): 4, ('uc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 20
# Most frequent pair: ('woo', 'd')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 13, 'm': 1, 'uc': 5, 'h': 5, 'wood': 4, 'c': 6, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', '</w>'): 2, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'c'): 2, ('c', 'h'): 4, ('h', 'uc'): 4, ('uc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 20
# Most frequent pair: ('c', 'h')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 13, 'm': 1, 'uc': 5, 'h': 1, 'wood': 4, 'c': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'ch': 4, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 17
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', '</w>'): 2, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'ch'): 2, ('ch', 'uc'): 4, ('uc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 19
# Most frequent pair: ('ch', 'uc')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 13, 'm': 1, 'uc': 1, 'h': 1, 'wood': 4, 'c': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'chuc': 4, 'k': 4, 'i': 1, 'f': 1})
# Number of tokens: 17
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', '</w>'): 2, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuc'): 2, ('chuc', 'k'): 4, ('k', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 18
# Most frequent pair: ('chuc', 'k')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 13, 'm': 1, 'uc': 1, 'h': 1, 'wood': 4, 'c': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'chuck': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', '</w>'): 2, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck'): 2, ('chuck', '</w>'): 4, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 17
# Most frequent pair: ('chuck', '</w>')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 9, 'm': 1, 'uc': 1, 'h': 1, 'wood': 4, 'c': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', '</w>'): 2, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 16
# Most frequent pair: ('wood', '</w>')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 3, 'w': 1, '</w>': 7, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'c': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 17
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('c', 'o'): 2, ('o', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 15
# Most frequent pair: ('c', 'o')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 7, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'co': 2, 'u': 2, 'l': 2, 'd': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 17
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('co', 'u'): 2, ('u', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 14
# Most frequent pair: ('co', 'u')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 7, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'cou': 2, 'l': 2, 'd': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 16
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('cou', 'l'): 2, ('l', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 13
# Most frequent pair: ('cou', 'l')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 7, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'coul': 2, 'd': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 15
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('coul', 'd'): 2, ('d', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 12
# Most frequent pair: ('coul', 'd')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 7, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 14
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('could', '</w>'): 2, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 11
# Most frequent pair: ('could', '</w>')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 5, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could</w>': 2, 'a': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 14
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('a', '</w>'): 2, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 10
# Most frequent pair: ('a', '</w>')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 3, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'wood': 2, 'chuck</w>': 4, 'i': 1, 'f': 1})
# Number of tokens: 14
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('wood', 'chuck</w>'): 2, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 9
# Most frequent pair: ('wood', 'chuck</w>')
# Tokens: defaultdict(<class 'int'>, {'H': 1, 'o': 1, 'w': 1, '</w>': 3, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 14
# Pairs: defaultdict(<class 'int'>, {('H', 'o'): 1, ('o', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 8
# Most frequent pair: ('H', 'o')
# Tokens: defaultdict(<class 'int'>, {'Ho': 1, 'w': 1, '</w>': 3, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 13
# Pairs: defaultdict(<class 'int'>, {('Ho', 'w'): 1, ('w', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 7
# Most frequent pair: ('Ho', 'w')
# Tokens: defaultdict(<class 'int'>, {'How': 1, '</w>': 3, 'm': 1, 'uc': 1, 'h': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 12
# Pairs: defaultdict(<class 'int'>, {('How', '</w>'): 1, ('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 6
# Most frequent pair: ('How', '</w>')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'm': 1, 'uc': 1, 'h': 1, '</w>': 2, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 12
# Pairs: defaultdict(<class 'int'>, {('m', 'uc'): 1, ('uc', 'h'): 1, ('h', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 5
# Most frequent pair: ('m', 'uc')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'muc': 1, 'h': 1, '</w>': 2, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 11
# Pairs: defaultdict(<class 'int'>, {('muc', 'h'): 1, ('h', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 4
# Most frequent pair: ('muc', 'h')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'much': 1, '</w>': 2, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1})
# Number of tokens: 10
# Pairs: defaultdict(<class 'int'>, {('much', '</w>'): 1, ('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 3
# Most frequent pair: ('much', '</w>')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'much</w>': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'i': 1, 'f': 1, '</w>': 1})
# Number of tokens: 10
# Pairs: defaultdict(<class 'int'>, {('i', 'f'): 1, ('f', '</w>'): 1})
# Number of distinct pairs: 2
# Most frequent pair: ('i', 'f')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'much</w>': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'if': 1, '</w>': 1})
# Number of tokens: 9
# Pairs: defaultdict(<class 'int'>, {('if', '</w>'): 1})
# Number of distinct pairs: 1
# Most frequent pair: ('if', '</w>')
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'much</w>': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'if</w>': 1})
# Number of tokens: 8

# %%
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
print('Vocabulary: {}'.format(vocab))
print('Size of vocabulary: {}'.format(len(vocab)))
# Out:
# Tokens: defaultdict(<class 'int'>, {'How</w>': 1, 'much</w>': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'if</w>': 1})
# Number of tokens: 8
# Vocabulary: {'How</w>': 1, 'much</w>': 1, 'wood</w>': 2, 'could</w>': 2, 'a</w>': 2, 'woodchuck</w>': 2, 'chuck</w>': 2, 'if</w>': 1}
# Size of vocabulary: 8

# %% [markdown]
# TODO - Consider the input text:
#
# "How much wood could a woodchuck chuck if a woodchuck could chuck wood"
#
# How many tokens will there be initially and what will they be?
# How many tokens will there be if we run the tokenization routine for the maximum number of iterations (merges)?
#
# When you've made your predictions, run the code and see if you are correct.
